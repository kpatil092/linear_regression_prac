# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate synthetic data
np.random.seed(42)
N = 100000
X = 2 * np.random.randn(N, 1)
# print(X)
true_w, true_b = 3, 4
noise = np.random.randn(N, 1)
y = true_w * X + true_b + noise
print(y)
# Out:
# [[8.01087951]
#  [2.01505943]
#  [8.46156842]
#  ...
#  [6.61513043]
#  [3.58912306]
#  [3.65542968]]

# %%
# Initialize parameters
w, b = np.random.randn(), np.random.randn()
print(f"Initial w: {w}, b: {b}")
lr = 0.1
decay = 0.01
epochs = 100
# Out:
# Initial w: 1.5618407128781946, b: -0.0942283119712064

# %%
# Training with Gradient Descent
loss_history = []
lr_history = []
for epoch in range(epochs):
    y_pred = w * X + b
    loss = np.mean((y_pred - y) ** 2)
    loss_history.append(loss)
    
    
    # Compute gradients
    dw = (2/N) * np.sum((y_pred - y) * X)
    db = (2/N) * np.sum(y_pred - y)
    
    # Update parameters
    w -= lr * dw
    b -= lr * db

        # Learning rate decay
    lr = lr / (1 + decay * epoch)
    lr_history.append(lr)

    if epoch % 10 == 0:
        print(f"Epoch {epoch}: Loss = {loss:.4f}, w = {w:.4f}, b = {b:.4f}")
# Out:
# Epoch 0: Loss = 26.1159, w = 2.7186, b = 0.7254
# Epoch 10: Loss = 1.3201, w = 3.0035, b = 3.5067
# Epoch 20: Loss = 1.0568, w = 3.0033, b = 3.7664
# Epoch 30: Loss = 1.0405, w = 3.0033, b = 3.7952
# Epoch 40: Loss = 1.0393, w = 3.0033, b = 3.7975
# Epoch 50: Loss = 1.0392, w = 3.0033, b = 3.7976
# Epoch 60: Loss = 1.0392, w = 3.0033, b = 3.7976
# Epoch 70: Loss = 1.0392, w = 3.0033, b = 3.7976
# Epoch 80: Loss = 1.0392, w = 3.0033, b = 3.7976
# Epoch 90: Loss = 1.0392, w = 3.0033, b = 3.7976

# %%
plt.plot(loss_history)
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.title('Training Loss over Time')
plt.show()

# %%
plt.plot(lr_history)
plt.xlabel('Epochs')
plt.ylabel('Learning Rate')
plt.title('Learning Rate Schedule')
plt.show()

# %%
plt.scatter(X, y, color='blue', label='Data Points')
plt.plot(X, w * X + b, color='red', label='Fitted Line')
plt.legend() 
plt.show()

# %%
print(f"Estimated parameters: w={w:.3f}, b={b:.3f}")
# Out:
# Estimated parameters: w=3.003, b=3.798
